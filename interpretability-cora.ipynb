# %%
from dgl.data import CoraGraphDataset
import networkx as nx
import numpy as np
import pandas as pd
import torch
# import matplotlib.pyplot as plt
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
dataset = CoraGraphDataset()
# Out:
#   NumNodes: 2708
#   NumEdges: 10556
#   NumFeats: 1433
#   NumClasses: 7
#   NumTrainingSamples: 140
#   NumValidationSamples: 500
#   NumTestSamples: 1000
# Done loading data from cached files.

# %%
# graph
graph = dataset[0]
num_classes = dataset.num_classes

feat = graph.ndata['feat']

train_mask = graph.ndata['train_mask']
val_mask = graph.ndata['val_mask']
test_mask = graph.ndata['test_mask']

label = graph.ndata['label']

# %%
# Converting the Cora graph dataset to Networkx graph
nx_graph = graph.to_networkx()

# %%
# feat.shape -> [number of samples, number of features]
# num_classes -> 7 
# label.shape -> [number of samples]
train_mask.shape
# Out:
# torch.Size([2708])

# %%
print(label)
# Out:
# tensor([3, 4, 4,  ..., 3, 3, 3])

# %%
data = torch.cat([feat,label.unsqueeze(dim=1)],dim=1)

# %%
def count_of_each_class(label):
    from collections import defaultdict 
    mp = defaultdict(int)
    for v in label.tolist():
        mp[v] += 1

    return mp

# %%
count_of_each_class(label)
# Out:
# defaultdict(int, {3: 818, 4: 426, 0: 351, 2: 418, 1: 217, 5: 298, 6: 180})

# %%
label[train_mask]
# Out:
# tensor([3, 4, 4, 0, 3, 2, 0, 3, 3, 2, 0, 0, 4, 3, 3, 3, 2, 3, 1, 3, 5, 3, 4, 6,
#         3, 3, 6, 3, 2, 4, 3, 6, 0, 4, 2, 0, 1, 5, 4, 4, 3, 6, 6, 4, 3, 3, 2, 5,
#         3, 4, 5, 3, 0, 2, 1, 4, 6, 3, 2, 2, 0, 0, 0, 4, 2, 0, 4, 5, 2, 6, 5, 2,
#         2, 2, 0, 4, 5, 6, 4, 0, 0, 0, 4, 2, 4, 1, 4, 6, 0, 4, 2, 4, 6, 6, 0, 0,
#         6, 5, 0, 6, 0, 2, 1, 1, 1, 2, 6, 5, 6, 1, 2, 2, 1, 5, 5, 5, 6, 5, 6, 5,
#         5, 1, 6, 6, 1, 5, 1, 6, 5, 5, 5, 1, 5, 1, 1, 1, 1, 1, 1, 1])

# %%
count_of_each_class(label[test_mask])
# Out:
# defaultdict(int, {3: 319, 2: 144, 0: 130, 1: 91, 5: 103, 4: 149, 6: 64})

# %%
from cora_sample_train_increment import new_y_train

# %%
new_y_train.squeeze(dim=1).tolist()
# Out:
# [3,
#  4,
#  4,
#  0,
#  3,
#  2,
#  0,
#  3,
#  3,
#  2,
#  0,
#  0,
#  4,
#  3,
#  3,
#  3,
#  2,
#  3,
#  1,
#  3,
#  5,
#  3,
#  4,
#  6,
#  3,
#  3,
#  6,
#  3,
#  2,
#  4,
#  3,
#  6,
#  0,
#  4,
#  2,
#  0,
#  1,
#  5,
#  4,
#  4,
#  3,
#  6,
#  6,
#  4,
#  3,
#  3,
#  2,
#  5,
#  3,
#  4,
#  5,
#  3,
#  0,
#  2,
#  1,
#  4,
#  6,
#  3,
#  2,
#  2,
#  0,
#  0,
#  0,
#  4,
#  2,
#  0,
#  4,
#  5,
#  2,
#  6,
#  5,
#  2,
#  2,
#  2,
#  0,
#  4,
#  5,
#  6,
#  4,
#  0,
#  0,
#  0,
#  4,
#  2,
#  4,
#  1,
#  4,
#  6,
#  0,
#  4,
#  2,
#  4,
#  6,
#  6,
#  0,
#  0,
#  6,
#  5,
#  0,
#  6,
#  0,
#  2,
#  1,
#  1,
#  1,
#  2,
#  6,
#  5,
#  6,
#  1,
#  2,
#  2,
#  1,
#  5,
#  5,
#  5,
#  6,
#  5,
#  6,
#  5,
#  5,
#  1,
#  6,
#  6,
#  1,
#  5,
#  1,
#  6,
#  5,
#  5,
#  5,
#  1,
#  5,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  1,
#  4,
#  3,
#  0,
#  3,
#  6,
#  6,
#  0,
#  3,
#  4,
#  0,
#  3,
#  4,
#  4,
#  1,
#  2,
#  2,
#  2,
#  3,
#  3,
#  3,
#  3,
#  0,
#  4,
#  5,
#  0,
#  3,
# ...

# %%
count_of_each_class(new_y_train.squeeze(dim=1))
# Out:
# defaultdict(int, {3: 178, 4: 101, 0: 81, 2: 98, 1: 56, 5: 77, 6: 49})
